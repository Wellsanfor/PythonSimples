# %% [markdown]
# Aprendendo python

# %%
6+6
# Out:
# 12

# %%
x = 10
y = 20
resultado = x + y
print(f"A soma de {x} e {y} é {resultado}")
# Out:
# A soma de 10 e 20 é 30

# %%
print("teste")
# Out:
# teste
